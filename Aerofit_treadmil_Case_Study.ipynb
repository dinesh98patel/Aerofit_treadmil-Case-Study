# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("aerofit_treadmill.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   KP781   40   Male         21        Single      6        5   83416
# 176   KP781   42   Male         18        Single      5        4   89641
# 177   KP781   45   Male         16        Single      5        5   90886
# 178   KP781   47   Male         18     Partnered      4        5  104581
# 179   KP781   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
# to check the length of dataframe
len(df)
# Out:
# 180

# %%
# find shape of dataframe
df.shape
# Out:
# (180, 9)

# %%
#check the size of dataframe
df.size
# Out:
# 1620

# %%
# info about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# ...

# %%
df.describe(include='object')
# Out:
#        Product Gender MaritalStatus
# count      180    180           180
# unique       3      2             2
# top      KP281   Male     Partnered
# freq        80    104           107

# %%
# to check if there any duplicate value present or not
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Product, Age, Gender, Education, MaritalStatus, Usage, Fitness, Income, Miles]
# Index: []

# %%
#To count the occurrences of each unique value in the specified columns.
df.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
#To count age value count
df['Age'].value_counts()
# Out:
# 25    25
# 23    18
# 24    12
# 26    12
# 28     9
# 35     8
# 33     8
# 30     7
# 38     7
# 21     7
# 22     7
# 27     7
# 31     6
# 34     6
# 29     6
# 20     5
# 40     5
# 32     4
# 19     4
# 48     2
# 37     2
# 45     2
# 47     2
# 46     1
# 50     1
# 18     1
# 44     1
# 43     1
# 41     1
# 39     1
# 36     1
# 42     1
# Name: Age, dtype: int64

# %%
df.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %% [markdown]
# It will returns the count of unique value in each coloumn of the dataset.

# %%
df.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# It will  returns the number of missing value of each column.

# %%
# It will return the mean values for each column in the DataFrame
df.mean()
# Out:
# <ipython-input-8-6e7660ee9208>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Age             28.788889
# Education       15.572222
# Usage            3.455556
# Fitness          3.311111
# Income       53719.577778
# Miles          103.194444
# dtype: float64

# %%
# It will return the median values for each column in the DataFrame
df.median()
# Out:
# <ipython-input-17-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Age             26.0
# Education       16.0
# Usage            3.0
# Fitness          3.0
# Income       50596.5
# Miles           94.0
# dtype: float64

# %%
#to count the gender value counts
df['Gender'].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
sns.countplot(data=df, x='Gender')
plt.show()

# %% [markdown]
# Thare are more Males in the data than Females.

# %%
df['MaritalStatus'].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
sns.countplot(data=df, x='MaritalStatus')
plt.title('MaritalStatus Wise Distribution ')
plt.show()

# %% [markdown]
# Most products purchased by Partnered customer category.

# %%
df['Usage'].value_counts()
# Out:
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: Usage, dtype: int64

# %%
sns.countplot(data=df, x='Usage')
plt.show()

# %%
df['Fitness'].value_counts()
# Out:
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: Fitness, dtype: int64

# %%
sns.countplot(data=df, x='Fitness')
plt.show()

# %% [markdown]
# highest number of customers have rated their physical fitness rating as Average

# %%
df['Product'].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
sns.countplot(data=df, x='Product')
plt.title('Product Wise Distribution')
plt.show()

# %% [markdown]
# KP281 is the most frequent product.

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x='Gender', hue='Product', data=df)
plt.title('Gender Wise Total Product Distribution')
plt.show()

# %% [markdown]
#  Males purchase higher number of KP781 treadmill as compare to female customer.and There are nearly equal number of male & female who purchase KP281 and KP481 treadmill.

# %%
plt.figure(figsize = (10, 7))
sns.countplot(data=df, x='Age')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Minimum & Maximum age of the person is 18 & 50, mean is 25 and 75% of persons have age less than or equal to 33.

# %%
plt.figure(figsize = (10, 7))
sns.countplot(data=df, x='Education')
plt.xticks(rotation=90)
plt.title('Education Wise Total Product Distribution')
plt.show()

# %% [markdown]
# Most of the people are having 16 years of education i.e. 75% of persons are having education <= 16 years.

# %%
plt.figure(figsize=(12,6))
ax = sns.countplot(x='MaritalStatus', hue='Product', data=df)
plt.title('Marital Status Wise Total Product Distribution')
plt.xlabel('Usage')
plt.ylabel('Total count')
plt.show()

# %% [markdown]
# Partnered/Married people purchased more treadmills as compare to single people.

# %%
sns.histplot(data=df, x="Income")
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Count of Customers')
plt.show()

# %%
# Product purchased Customers Income and their Gender
plt.figure(figsize=(12,5))
sns.kdeplot(data=df,x='Income',hue='Gender')
plt.show()

# %% [markdown]
# From above graphe we can conclude that the spike  40K to around 80K is the most common income per annum of the customers

# %%
# It use to group the product based on income.
df.groupby('Product')['Income'].describe()
# Out:
#          count       mean           std      min       25%      50%      75%  \
# Product
# KP281     80.0  46418.025   9075.783190  29562.0  38658.00  46617.0  53439.0
# KP481     60.0  48973.650   8653.989388  31836.0  44911.50  49459.5  53439.0
# KP781     40.0  75441.575  18505.836720  48556.0  58204.75  76568.5  90886.0
#
#               max
# Product
# KP281     68220.0
# KP481     67083.0
# KP781    104581.0

# %%
sns.boxplot(data=df, x='Gender',y='Income', hue='Product')
plt.show()

# %% [markdown]
# As Above graph we can pind that product KB781 have hogh profit Margin.

# %%
sns.boxplot(data=df, x='Gender', y='Miles', hue='Product')
plt.show()

# %% [markdown]
# Customer who purchased KP781 product are running more miles and more fit.

# %%
#It will creates a crosstab between Gender and Product column and cross tab use for create cross tabular form between two or mor factor.
round(pd.crosstab(df['Product'],df['Gender'],margins=True,normalize=True)*100,2)
# Out:
# Gender   Female   Male     All
# Product
# KP281     22.22  22.22   44.44
# KP481     16.11  17.22   33.33
# KP781      3.89  18.33   22.22
# All       42.22  57.78  100.00

# %% [markdown]
# Product KP781 most preferred by Male customer than Female customers.

# %%
crosstab=round(pd.crosstab(df['Product'],df['Fitness'],margins=True,normalize=True)*100,2)
crosstab
# Out:
# Fitness     1      2      3      4      5     All
# Product
# KP281    0.56   7.78  30.00   5.00   1.11   44.44
# KP481    0.56   6.67  21.67   4.44   0.00   33.33
# KP781    0.00   0.00   2.22   3.89  16.11   22.22
# All      1.11  14.44  53.89  13.33  17.22  100.00

# %% [markdown]
# Probability of purchase of KP281 = 44.44%
#
# Probability of purchase of KP481 = 33.33%
#
# Probability of purchase of KP781 = 22.22%

# %%
sns.barplot = crosstab.plot.bar(rot=0)

# %% [markdown]
#  In A week more the 3 dayes most customer usage thje product and most of customer prefer KP781 Product as well

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(10,8))
sns.boxplot(data=df, x='Age', ax=ax[0,0]);                      ax[0,0].set_title('Age - Outliers')
sns.boxplot(data=df, x='Education', ax=ax[0,1], color='orange'); ax[0,1].set_title('Education - Outliers')
sns.boxplot(data=df, x='Income', ax=ax[1,0], color='cyan');     ax[1,0].set_title('Income - Outliers')
sns.boxplot(data=df, x='Miles', ax=ax[1,1], color='purple');    ax[1,1].set_title('Miles - Outliers')
sns.boxplot(data=df, x='Usage', ax=ax[2,0], color='yellow');    ax[2,0].set_title('Usage - Outliers')
sns.boxplot(data=df, x='Fitness', ax=ax[2,1], color='pink');     ax[2,1].set_title('Fitness - Outliers')
# Out:
# Text(0.5, 1.0, 'Fitness - Outliers')

# %% [markdown]
# From Above Graph we can anmalyses that:
#
# Income and Miles found to have more outliers than other attributes.
# 75% of customers have age less than 33.
# 75% of customers earning less than 60k.
# 75% of customers are fitness people more than 3.

# %%
# categories the product and storing
p1 = df[df['Product']=='KP281']
p2 = df[df['Product']=='KP481']
p3 = df[df['Product']=='KP781']

# %%
fig,ax = plt.subplots(nrows=3, ncols=1, figsize=(8,15))
sns.histplot(p1['Income'], kde=True, bins=20, ax=ax[0], color='green'); ax[0].set_title("KP281 Customers Annual Income")
sns.histplot(p2['Income'], kde=True, bins=20, ax=ax[1], color='orange'); ax[1].set_title("KP481 Customers Annual Income")
sns.histplot(p3['Income'], kde=True, bins=20, ax=ax[2], color='red'); ax[2].set_title("KP781 Customers Annual Income")
# Out:
# Text(0.5, 1.0, 'KP781 Customers Annual Income')

# %% [markdown]
# 30K to 70K earning customer bougth the product KP281 & KP481

# %%
df_female=df[df['Gender']=='Female']
df_male=df[df['Gender']=='Male']
fig,ax=plt.subplots(nrows=1, ncols=2, figsize=(8,5))
sns.countplot(data=df_male, x='Product', hue='MaritalStatus',ax=ax[0],color='yellow'); ax[0].set_title('Male customer')
sns.countplot(data=df_female, x='Product', hue='MaritalStatus',ax=ax[1],color='green'); ax[1].set_title('Female Customer')
# Out:
# Text(0.5, 1.0, 'Female Customer')

# %% [markdown]
# People who use the treadmill more are more likely to purchase KP781 i.e 4 to 6 times in a week. And people who use the treadmill moderate i.e. 2 to 4 times in a week is more likely to purchase KP281 and KP481.

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <ipython-input-14-6dc1c4c1753e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %% [markdown]
# From above map we can find that people who run more whos usage is Highter and his fitness is also good.

# %%
plt.figure(figsize=(4,4))
sns.pairplot(data=df, hue ='Product', palette= 'flare')

# %% [markdown]
# Marital Status has smaller correlation between Age and Income.
#
# Income is highly correlated with Product and Education. It also had good correlation with Age, usage, Fitness, Miles.

# %% [markdown]
# **KP281**
#
#
# KP281 is the most popular product among the entry level customers.
#
# This product is easily afforded by both Male and Female customers.
#
# Product is used 3 to 4 times a week.
#
# Younger to Elder beginner level customers prefer this product.
#
# Single female & Partnered male customers bought this product more than single male customers.
#
#
# **KP481**
#
# This is an Intermediate level Product.
#
# KP481 is the second most popular product among the customers.
#
# Customers Prefer this product mostly to cover more miles than fitness.
#
# More Female customers prefer this product than males.
#
# Probability of Female customer buying KP481 is significantly higher than male.
#
# Average Income of the customer who buys KP481 is 49K.
#
# Average Usage of this product is 3 days per week.
#
# More Partnered customers prefer this product.
#
# The buyers of KP481 in Single & Partnered, Male & Female are same.
#
#
# **KP781**
#
# Due to the High Price & being the advanced type, customer prefers less of this product.
#
# Customers use this product mainly to cover more distance.
#
# Customers who use this product have rated excelled shape as fitness rating.
#
# Customers use 4 to 5 times a week at least.
#
# Probability of a single person buying KP781 is higher than Married customers. So , KP781 is also recommended for people who are single and exercises more.
#
# Average Income of KP781 buyers are over 75K per annum
#
# This product is preferred by the customer where the correlation between Education and Income is High.

# %% [markdown]
# **Business Insights:**
#
#
# Males have high chances of purchase KP781 treadmill And both are likely to purchase equal number of KP281 and KP481 treadmill.
#
# People with Education level less than or equal to 16 years are more likely to purchase KP281 and KP481 treadmill.
#
# People with annual Income less than or equal to $70000 are more likely to purchase KP281 and KP481 treadmill
#
# People who use the treadmill more are more likely to purchase KP781 i.e 4 to 6 times in a week. And people who use the treadmill moderate i.e. 2 to 4 times in a week is more likely to purchase KP281 and KP481.
#
# People who use the treadmill more are more likely to purchase KP781.
#
# **Recommendation:**
#
#  As KP781 premium product preferred by Males, more usage and high salaried people, we can promote this product with similar characteristics and also we can promote upcoming premium products to them.
#
#  KP281 & KP481 products preferred by almost similar Characteristics and KP281 is most sold product, we can promote KP481 products more. and aslo we can provide some Offer.
#
#  Provide personalized Ads in E-commerce sites and in Social Media for better reach to similar characteristics of people with respective preferred products.
#
#  Aerofit should run a some reward point program to encourage customer to increase thier weekly usage of the treadmill in each week
